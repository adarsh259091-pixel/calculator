# %% [markdown]
# <a href="https://colab.research.google.com/github/adarsh259091-pixel/calculator/blob/main/sales_data_supermarket.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df=pd.read_csv("annex1 (1).csv")

# %%
df
df.head()
# Out:
#          Item Code              Item Name  Category Code  \
# 0  102900005115168       Niushou Shengcai     1011010101
# 1  102900005115199      Sichuan Red Cedar     1011010101
# 2  102900005115625  Local Xiaomao Cabbage     1011010101
# 3  102900005115748           White Caitai     1011010101
# 4  102900005115762               Amaranth     1011010101
#
#             Category Name
# 0  Flower/Leaf Vegetables
# 1  Flower/Leaf Vegetables
# 2  Flower/Leaf Vegetables
# 3  Flower/Leaf Vegetables
# 4  Flower/Leaf Vegetables

# %%
df
df.tail()
# Out:
#            Item Code                                     Item Name  \
# 246  106958851400125                    Haixian Mushroom (Bag) (4)
# 247  106971533450003                      Haixian Mushroom (Bunch)
# 248  106971533455008                    Haixian Mushroom (Bag) (3)
# 249  106973223300667  Chinese Caterpillar Fungus Flowers (Box) (2)
# 250  106973990980123                 Hfyg Haixian Mushroom (Bunch)
#
#      Category Code    Category Name
# 246     1011010801  Edible Mushroom
# 247     1011010801  Edible Mushroom
# 248     1011010801  Edible Mushroom
# 249     1011010801  Edible Mushroom
# 250     1011010801  Edible Mushroom

# %%
df
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 251 entries, 0 to 250
# Data columns (total 4 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Item Code      251 non-null    int64
#  1   Item Name      251 non-null    object
#  2   Category Code  251 non-null    int64
#  3   Category Name  251 non-null    object
# dtypes: int64(2), object(2)
# memory usage: 8.0+ KB

# %%
df
df.describe()
# Out:
#           Item Code  Category Code
# count  2.510000e+02   2.510000e+02
# mean   1.031908e+14   1.011010e+09
# std    1.048400e+12   2.915469e+02
# min    1.029000e+14   1.011010e+09
# 25%    1.029000e+14   1.011010e+09
# 50%    1.029000e+14   1.011011e+09
# 75%    1.029000e+14   1.011011e+09
# max    1.069740e+14   1.011011e+09

# %%
df
df.shape
# Out:
# (251, 4)

# %%
df
df.size
# Out:
# 1004

# %% [markdown]
# #missingvalu/ null

# %%
df.isnull().sum()
# Out:
# Item Code        0
# Item Name        0
# Category Code    0
# Category Name    0
# dtype: int64

# %%
sns.distplot(df['Category Code'])
# Out:
# /tmp/ipython-input-1955801475.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df['Category Code'])
# <Axes: xlabel='Category Code', ylabel='Density'>

# %% [markdown]
# #bivariate analysis

# %%
df.columns
# Out:
# Index(['Item Code', 'Item Name', 'Category Code', 'Category Name'], dtype='object')

# %%
sns.jointplot(x='Item Name',y='Category Name',data=df)

# %%
from sklearn.preprocessing import LabelEncoder
le=LabelEncoder()
df['Item Name']=le.fit_transform(df['Item Name'])
df['Category Name']=le.fit_transform(df['Category Name'])
df['Category Name']=le.fit_transform(df['Category Name'])

# %%
df.corr
# Out:
# <bound method DataFrame.corr of            Item Code  Item Name  Category Code  Category Name
# 0    102900005115168        142     1011010101              4
# 1    102900005115199        176     1011010101              4
# 2    102900005115625        112     1011010101              4
# 3    102900005115748        207     1011010101              4
# 4    102900005115762          6     1011010101              4
# ..               ...        ...            ...            ...
# 246  106958851400125         82     1011010801              3
# 247  106971533450003         83     1011010801              3
# 248  106971533455008         81     1011010801              3
# 249  106973223300667         38     1011010801              3
# 250  106973990980123         85     1011010801              3
#
# [251 rows x 4 columns]>

# %%
plt.figure(figsize=(4,3))
sns.heatmap(df.corr())
plt.show()

# %%
df.nunique()
# Out:
# Item Code        251
# Item Name        247
# Category Code      6
# Category Name      6
# dtype: int64
